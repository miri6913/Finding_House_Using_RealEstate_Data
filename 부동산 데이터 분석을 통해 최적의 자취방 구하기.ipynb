# %% [markdown]
# # **부동산 데이터: 최적의 자취방 구하기**

# %% [markdown]
# ## **크롤링**

# %%
from user_agent import generate_user_agent, generate_navigator
user_agent = generate_user_agent()
user_agent
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:48.0) Gecko/20100101 Firefox/48.0'

# %%
import requests
import numpy as np
import pandas as pd

# %%
from tqdm.notebook import tqdm
import time

# %%
article_list = []
for i in tqdm(range(1, 101)):
    try:
        url = f'https://m.land.naver.com/cluster/ajax/articleList?itemId=&mapKey=&lgeo=&showR0=&rletTpCd=OPST%3AVL%3AOR&tradTpCd=B2&z=12&lat=37.481021&lon=126.951601&btm=37.3398975&lft=126.6762562&top=37.6218785&rgt=127.2269458&totCnt=8360&cortarNo=1162000000&sort=rank&page={i}'

        user_agent = generate_user_agent()
        headers = {'User-Agent':user_agent}

        res = requests.get(url, headers=headers)
        time.sleep(1)

        article_json = res.json()
        article_body = article_json['body']
        article_list.append(article_body)
    except:
        break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
article_list1 = [j for i in article_list for j in i]

# %%
data = pd.DataFrame(article_list1)

# %%
data = data[['atclNo','rletTpNm','flrInfo','rentPrc','hanPrc','spc1','spc2','direction','atclCfmYmd','repImgUrl','lat','lng','atclFetrDesc','tagList']]
data.columns = ['물건번호','구분','층수(물건층/전체층)','월세','보증금','계약면적(m2)','전용면적(m2)','방향','확인일자','이미지','위도','경도','설명','태그']
data
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세    보증금 계약면적(m2) 전용면적(m2)   방향  \
# 0     2419918257  원룸         저/4   40    300       19    16.53  남서향
# 1     2419934436  원룸         1/5   40  2,000       21       18  남동향
# 2     2419858607  원룸       10/12  105  5,000       26     23.1  남동향
# 3     2419914550  원룸         저/3   32    500       19     19.8  남서향
# 4     2419768826  원룸        B1/5   30  1,000       18       15   서향
# ...          ...  ..         ...  ...    ...      ...      ...  ...
# 1775  2419458867  원룸         3/4   35    300       23     19.8  남동향
# 1776  2419452608  원룸         고/4   40    300       26    23.14  남동향
# 1777  2419452139  원룸         3/4   35    500       26    23.14  남동향
# 1778  2419452826  원룸         1/3   54  1,000        -    26.44  북동향
# 1779  2419452767  원룸         고/3   35    300       23    19.84  남동향
#
#            확인일자                                                이미지         위도  \
# 0     24.04.24.  /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710
# 1     24.04.24.  /20240424_52/land_naver_1713951003188lUMzH_JPE...  37.480955
# 2     24.04.24.  /20240424_243/land_naver_1713952441796YW8Nf_JP...  37.478109
# 3     24.04.24.  /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110
# 4     24.04.24.  /20240424_299/land_naver_1713953221116pxTcd_JP...  37.478232
# ...         ...                                                ...        ...
# 1775  24.04.22.  /20240422_251/land_naver_1713745673469CcBwe_JP...  37.477821
# 1776  24.04.22.  /20240422_141/land_naver_17137455375894ggHz_JP...  37.486339
# 1777  24.04.22.  /20240422_47/land_naver_1713745220011NfDDB_JPE...  37.484921
# 1778  24.04.22.  /20240422_201/land_naver_1713745434912bAgDx_JP...  37.486167
# 1779  24.04.22.  /20240422_259/land_naver_1713755089278QSwLk_JP...  37.483517
#
#               경도                                     설명                    태그
# 0     126.911921           2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO    [4년이내, 융자금적은, 역세권]
# 1     126.900701         구디역 이쁜 화이트 원룸현황1.5층깔끔 풀옵션 원룸월세     [4년이내, 융자금적은, 1층]
# 2     126.962245  낙성대역 5번출구 도보1분 초역세권 1.5룸 매우 깨끗하고 예쁜 방    [2년이내, 융자금적은, 역세권]
# 3     126.967600                     2호선 역세권 가성비 좋은 풀옵션   [25년이내, 역세권, 화장실한개]
# 4     126.961926                        낙성대 초역세권 즉시입주가능   [25년이내, 융자금적은, 역세권]
# ...          ...                                    ...                   ...
# 1775  126.935265               신림역 채광 NO.1역도보7분양창원룸채광최강   [25년이내, 융자금적은, 역세권]
# 1776  126.915350                      넓고 깔끔한 집입니다 초역세권    [25년이내, 융자금적은, 역세권]
# 1777  126.919564                      신축, 이쁜방 전세자금대출가능    [2년이내, 융자금적은, 소형평수]
# 1778  126.931098       신림 역세권 넓은 지상층 분리형 원룸. 공간 넓게 쓰실 분      [25년이상, 역세권, 1층]
# 1779  126.919409                     저렴한 분리형 원룸 방이 넓습니다  [10년이내, 융자금없는, 세대분리]
#
# [1780 rows x 14 columns]

# %%
data.to_excel('Data/data.xlsx')

# %% [markdown]
# ## **질문 만들기**

# %% [markdown]
# - 최적의 자취방 구하기
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %% [markdown]
# ## **데이터 전처리**

# %%
import plotly.express as px
import folium

import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_excel('/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습6: 직접 크롤링하기 - 부동산 데이터 분석을 통해 최적의 자취방 구하기/data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12064\2908586908.py in <module>
# ----> 1 data = pd.read_excel('/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습6: 직접 크롤링하기 - 부동산 데이터 분석을 통해 최적의 자취방 구하기/data.xlsx')
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1079             else:
#    1080                 ext = inspect_excel_format(
# -> 1081                     content=path_or_buffer, storage_options=storage_options
#    1082                 )
#    1083
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     957
#     958     with get_handle(
# --> 959         content_or_path, "rb", storage_options=storage_options, is_text=False
#     960     ) as handle:
#     961         stream = handle.handle
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     654         else:
#     655             # Binary mode
# --> 656             handle = open(handle, ioargs.mode)
#     657         handles.append(handle)
#     658
#
# OSError: [Errno 22] Invalid argument: '/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습6: 직접 크롤링하기 - 부동산 데이터 분석을 통해 최적의 자취방 구하기/data.xlsx'

# %%
data.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)   월세    보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0  2419918257  원룸         저/4   40    300       19    16.53  남서향  24.04.24.
# 1  2419934436  원룸         1/5   40  2,000       21       18  남동향  24.04.24.
# 2  2419858607  원룸       10/12  105  5,000       26     23.1  남동향  24.04.24.
# 3  2419914550  원룸         저/3   32    500       19     19.8  남서향  24.04.24.
# 4  2419768826  원룸        B1/5   30  1,000       18       15   서향  24.04.24.
#
#                                                  이미지         위도          경도  \
# 0  /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710  126.911921
# 1  /20240424_52/land_naver_1713951003188lUMzH_JPE...  37.480955  126.900701
# 2  /20240424_243/land_naver_1713952441796YW8Nf_JP...  37.478109  126.962245
# 3  /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110  126.967600
# 4  /20240424_299/land_naver_1713953221116pxTcd_JP...  37.478232  126.961926
#
#                                       설명                   태그
# 0           2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO   [4년이내, 융자금적은, 역세권]
# 1         구디역 이쁜 화이트 원룸현황1.5층깔끔 풀옵션 원룸월세    [4년이내, 융자금적은, 1층]
# 2  낙성대역 5번출구 도보1분 초역세권 1.5룸 매우 깨끗하고 예쁜 방   [2년이내, 융자금적은, 역세권]
# 3                     2호선 역세권 가성비 좋은 풀옵션  [25년이내, 역세권, 화장실한개]
# 4                        낙성대 초역세권 즉시입주가능  [25년이내, 융자금적은, 역세권]

# %%
data = data.iloc[:,1:]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1780 entries, 0 to 1779
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   구분           1780 non-null   object
#  1   층수(물건층/전체층)  1780 non-null   object
#  2   월세           1780 non-null   int64
#  3   보증금          1778 non-null   object
#  4   계약면적(m2)     1780 non-null   object
#  5   전용면적(m2)     1780 non-null   object
#  6   방향           1780 non-null   object
#  7   확인일자         1780 non-null   object
#  8   이미지          1590 non-null   object
#  9   위도           1780 non-null   float64
#  10  경도           1780 non-null   float64
#  11  설명           1663 non-null   object
#  12  태그           1780 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 180.9+ KB

# %% [markdown]
# - 월세 0원인 경우 제외

# %%
data = data.query('월세 > 0')

# %% [markdown]
# - 보증금 숫자로 변환

# %%
data['보증금'].unique()
# Out:
# array(['300', '2,000', '5,000', '500', '1,000', '100', '3,000', '200',
#        '20', '7,000', '50', '30', nan, '4,000', '3,500', '8,200',
#        '2억 7,000', '3억 2,000', '1억', '5,500', '2억', '1억 7,000', '2억 500',
#        '1억 2,000', '2억 4,900', '35', '8,000', '1억 3,000', '1억 5,000',
#        '9,500', '1억 6,700', '4억 6,000', '1억 4,000', '3억', '2억 3,000',
#        '2억 6,000', '7,500', '1억 9,000', '1억 395', '6,000', '2억 2,000',
#        '1억 7,500', '6,500', '3억 3,000', '1억 1,000', '1,500', '4억 5,000',
#        '1억 4,300', '2,500', '1억 9,600', '9,000', '1억 2,500', '3,700',
#        '1억 4,800', '2억 5,000', '2억 700', '3억 5,000', '1억 6,500', '400',
#        '1억 1,800', '1억 700', '1억 900', '1억 8,000', '1억 6,000', '9,540',
#        '9,990', '6,900', '7,300'], dtype=object)

# %%
data = data.query('~보증금.str.contains("억", na=False)')

# %%
data['보증금'].unique()
# Out:
# array(['300', '2,000', '5,000', '500', '1,000', '100', '3,000', '200',
#        '20', '7,000', '50', '30', nan, '4,000', '3,500', '8,200', '5,500',
#        '35', '8,000', '9,500', '7,500', '6,000', '6,500', '1,500',
#        '2,500', '9,000', '3,700', '400', '9,540', '9,990', '6,900',
#        '7,300'], dtype=object)

# %%
data['보증금'] = data['보증금'].dropna()

# %%
# Convert '보증금' column to string type and remove commas
data['보증금'] = data['보증금'].astype(str).str.replace(',', '')

# Convert string values to integers, ignoring errors (NaN values)
data['보증금'] = pd.to_numeric(data['보증금'], errors='coerce')

# Print unique values in the '보증금' column
print(data['보증금'].unique())
# Out:
# [ 300. 2000. 5000.  500. 1000.  100. 3000.  200.   20. 7000.   50.   30.
#    nan 4000. 3500. 8200. 5500.   35. 8000. 9500. 7500. 6000. 6500. 1500.
#  2500. 9000. 3700.  400. 9540. 9990. 6900. 7300.]

# %%
data['보증금'] = data['보증금'].str.replace(',','').astype(int)
data['보증금'].unique()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12064\188840418.py in <module>
# ----> 1 data['보증금'] = data['보증금'].str.replace(',','').astype(int)
#       2 data['보증금'].unique()
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# - 물건층과 전체층 분리 후 1층과 꼭대기층 유무 컬럼 만들기
#     - 지하의 경우 마이너스로 표시

# %%
data[['물건층','전체층']] = data['층수(물건층/전체층)'].str.split('/', expand=True)

# %%
data.head()
# Out:
#    구분 층수(물건층/전체층)   월세     보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0  원룸         저/4   40   300.0       19    16.53  남서향  24.04.24.
# 1  원룸         1/5   40  2000.0       21       18  남동향  24.04.24.
# 2  원룸       10/12  105  5000.0       26     23.1  남동향  24.04.24.
# 3  원룸         저/3   32   500.0       19     19.8  남서향  24.04.24.
# 4  원룸        B1/5   30  1000.0       18       15   서향  24.04.24.
#
#                                                  이미지         위도          경도  \
# 0  /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710  126.911921
# 1  /20240424_52/land_naver_1713951003188lUMzH_JPE...  37.480955  126.900701
# 2  /20240424_243/land_naver_1713952441796YW8Nf_JP...  37.478109  126.962245
# 3  /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110  126.967600
# 4  /20240424_299/land_naver_1713953221116pxTcd_JP...  37.478232  126.961926
#
#                                       설명                   태그 물건층 전체층
# 0           2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO   [4년이내, 융자금적은, 역세권]   저   4
# 1         구디역 이쁜 화이트 원룸현황1.5층깔끔 풀옵션 원룸월세    [4년이내, 융자금적은, 1층]   1   5
# 2  낙성대역 5번출구 도보1분 초역세권 1.5룸 매우 깨끗하고 예쁜 방   [2년이내, 융자금적은, 역세권]  10  12
# 3                     2호선 역세권 가성비 좋은 풀옵션  [25년이내, 역세권, 화장실한개]   저   3
# 4                        낙성대 초역세권 즉시입주가능  [25년이내, 융자금적은, 역세권]  B1   5

# %%
data['물건층'].unique()
# Out:
# array(['저', '1', '10', 'B1', '4', '2', '3', '6', '8', '고', '중', '5', '7',
#        '9', '12', '20', 'B2', '11', '13', '15'], dtype=object)

# %%
def floor_info(target, total):
    try:
        if target in ['B1','B2']: #지하이면
            return 'y'
        elif int(target) == 1 or int(target)/int(total) == 1: #1층이거나 꼭대기층이면
            return 'y'
        else:
            return 'n'
    except ValueError:
        return 'n'

# %%
data['비선호층여부'] = data.apply(lambda x: floor_info(x['물건층'], x['전체층']), axis=1)

# %%
data.head()
# Out:
#    구분 층수(물건층/전체층)   월세     보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0  원룸         저/4   40   300.0       19    16.53  남서향  24.04.24.
# 1  원룸         1/5   40  2000.0       21       18  남동향  24.04.24.
# 2  원룸       10/12  105  5000.0       26     23.1  남동향  24.04.24.
# 3  원룸         저/3   32   500.0       19     19.8  남서향  24.04.24.
# 4  원룸        B1/5   30  1000.0       18       15   서향  24.04.24.
#
#                                                  이미지         위도          경도  \
# 0  /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710  126.911921
# 1  /20240424_52/land_naver_1713951003188lUMzH_JPE...  37.480955  126.900701
# 2  /20240424_243/land_naver_1713952441796YW8Nf_JP...  37.478109  126.962245
# 3  /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110  126.967600
# 4  /20240424_299/land_naver_1713953221116pxTcd_JP...  37.478232  126.961926
#
#                                       설명                   태그 물건층 전체층 비선호층여부
# 0           2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO   [4년이내, 융자금적은, 역세권]   저   4      n
# 1         구디역 이쁜 화이트 원룸현황1.5층깔끔 풀옵션 원룸월세    [4년이내, 융자금적은, 1층]   1   5      y
# 2  낙성대역 5번출구 도보1분 초역세권 1.5룸 매우 깨끗하고 예쁜 방   [2년이내, 융자금적은, 역세권]  10  12      n
# 3                     2호선 역세권 가성비 좋은 풀옵션  [25년이내, 역세권, 화장실한개]   저   3      n
# 4                        낙성대 초역세권 즉시입주가능  [25년이내, 융자금적은, 역세권]  B1   5      y

# %% [markdown]
# - 제외 조건에 해당하는 매물 제외
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %%
#보증금 3000만원 이하
#지하, 반지하, 꼭대기층은 선호하지 않음
#북향은 선호하지 않음
data_filtered = data.query('300 <= 보증금 <= 3000 and 비선호층여부 == "n" and 전체층 != "1" and ~방향.str.contains("북")')

# %%
data_filtered
# Out:
#       구분 층수(물건층/전체층)  월세     보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0     원룸         저/4  40   300.0       19    16.53  남서향  24.04.24.
# 3     원룸         저/3  32   500.0       19     19.8  남서향  24.04.24.
# 11    원룸         저/4  30   500.0       19     19.8  남동향  24.04.24.
# 12    원룸         3/4  45  3000.0       23    23.14   서향  24.04.24.
# 13    원룸         6/8  50  1000.0       23     23.1   동향  24.04.24.
# ...   ..         ...  ..     ...      ...      ...  ...        ...
# 1773  원룸         저/3  37   300.0       36    33.06  남동향  24.04.22.
# 1775  원룸         3/4  35   300.0       23     19.8  남동향  24.04.22.
# 1776  원룸         고/4  40   300.0       26    23.14  남동향  24.04.22.
# 1777  원룸         3/4  35   500.0       26    23.14  남동향  24.04.22.
# 1779  원룸         고/3  35   300.0       23    19.84  남동향  24.04.22.
#
#                                                     이미지         위도  \
# 0     /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710
# 3     /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110
# 11    /20240425_96/land_naver_1714015501394lNLip_JPE...  37.469927
# 12    /20240424_240/land_naver_1713951961790HmQA3_JP...  37.486506
# 13    /20240424_181/land_naver_1713952142631HCCmx_JP...  37.480189
# ...                                                 ...        ...
# 1773  /20240422_253/land_naver_1713745347339MhVf4_JP...  37.479770
# 1775  /20240422_251/land_naver_1713745673469CcBwe_JP...  37.477821
# 1776  /20240422_141/land_naver_17137455375894ggHz_JP...  37.486339
# 1777  /20240422_47/land_naver_1713745220011NfDDB_JPE...  37.484921
# 1779  /20240422_259/land_naver_1713755089278QSwLk_JP...  37.483517
#
#               경도                                   설명                    태그  \
# 0     126.911921         2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO    [4년이내, 융자금적은, 역세권]
# 3     126.967600                   2호선 역세권 가성비 좋은 풀옵션   [25년이내, 역세권, 화장실한개]
# 11    126.965559             2호선 역세권 가성비 좋은 신축 대형 풀옵션  [10년이내, 화장실한개, 소형평수]
# 12    126.952803  2호선 역세권 넓은 1.5룸 가성비 최고 넓은집 찾는다면 여기요   [2년이내, 화장실한개, 소형평수]
# 13    126.945238    역6분 넓은방 깔끔컨디션 채광좋음 풀옵션 즉시입주가능 엘베有   [25년이내, 융자금없는, 역세권]
# ...          ...                                  ...                   ...
# 1773  126.928582            엄청 넓은 신축 원룸 입니다 퀸사이즈 침대가능   [15년이내, 융자금적은, 역세권]
# 1775  126.935265             신림역 채광 NO.1역도보7분양창원룸채광최강   [25년이내, 융자금적은, 역세권]
# 1776  126.915350                    넓고 깔끔한 집입니다 초역세권    [25년이내, 융자금적은, 역세권]
# 1777  126.919564                    신축, 이쁜방 전세자금대출가능    [2년이내, 융자금적은, 소형평수]
# 1779  126.919409                   저렴한 분리형 원룸 방이 넓습니다  [10년이내, 융자금없는, 세대분리]
#
#      물건층 전체층 비선호층여부
# 0      저   4      n
# 3      저   3      n
# 11     저   4      n
# 12     3   4      n
# 13     6   8      n
# ...   ..  ..    ...
# 1773   저   3      n
# 1775   3   4      n
# 1776   고   4      n
# 1777   3   4      n
# 1779   고   3      n
#
# [700 rows x 16 columns]

# %% [markdown]
# - 태그 컬럼 분리

# %%
data_filtered['태그'] = data_filtered['태그'].astype(str)

data_filtered[['tag1','tag2','tag3','tag4']] = data_filtered['태그'].str.replace("\'|\[|\]","").str.split(', ', expand=True)

# %%
data_filtered.head()
# Out:
#     구분 층수(물건층/전체층)  월세     보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0   원룸         저/4  40   300.0       19    16.53  남서향  24.04.24.
# 3   원룸         저/3  32   500.0       19     19.8  남서향  24.04.24.
# 11  원룸         저/4  30   500.0       19     19.8  남동향  24.04.24.
# 12  원룸         3/4  45  3000.0       23    23.14   서향  24.04.24.
# 13  원룸         6/8  50  1000.0       23     23.1   동향  24.04.24.
#
#                                                   이미지         위도          경도  \
# 0   /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710  126.911921
# 3   /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110  126.967600
# 11  /20240425_96/land_naver_1714015501394lNLip_JPE...  37.469927  126.965559
# 12  /20240424_240/land_naver_1713951961790HmQA3_JP...  37.486506  126.952803
# 13  /20240424_181/land_naver_1713952142631HCCmx_JP...  37.480189  126.945238
#
#                                      설명                          태그 물건층 전체층  \
# 0          2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO    ['4년이내', '융자금적은', '역세권']   저   4
# 3                    2호선 역세권 가성비 좋은 풀옵션   ['25년이내', '역세권', '화장실한개']   저   3
# 11             2호선 역세권 가성비 좋은 신축 대형 풀옵션  ['10년이내', '화장실한개', '소형평수']   저   4
# 12  2호선 역세권 넓은 1.5룸 가성비 최고 넓은집 찾는다면 여기요   ['2년이내', '화장실한개', '소형평수']   3   4
# 13    역6분 넓은방 깔끔컨디션 채광좋음 풀옵션 즉시입주가능 엘베有   ['25년이내', '융자금없는', '역세권']   6   8
#
#    비선호층여부   tag1   tag2   tag3  tag4
# 0       n   4년이내  융자금적은    역세권  None
# 3       n  25년이내    역세권  화장실한개  None
# 11      n  10년이내  화장실한개   소형평수  None
# 12      n   2년이내  화장실한개   소형평수  None
# 13      n  25년이내  융자금없는    역세권  None

# %% [markdown]
# - 연식 컬럼 추가

# %%
data_filtered = data_filtered.query('tag1.str.contains("년")') #연식 정보가 있는 데이터만 필터링

# %%
data_filtered['연식'] = [int(i[0]) for i in data_filtered['tag1'].str.split('년')]
data_filtered
# Out:
#       구분 층수(물건층/전체층)  월세     보증금 계약면적(m2) 전용면적(m2)   방향       확인일자  \
# 0     원룸         저/4  40   300.0       19    16.53  남서향  24.04.24.
# 3     원룸         저/3  32   500.0       19     19.8  남서향  24.04.24.
# 11    원룸         저/4  30   500.0       19     19.8  남동향  24.04.24.
# 12    원룸         3/4  45  3000.0       23    23.14   서향  24.04.24.
# 13    원룸         6/8  50  1000.0       23     23.1   동향  24.04.24.
# ...   ..         ...  ..     ...      ...      ...  ...        ...
# 1773  원룸         저/3  37   300.0       36    33.06  남동향  24.04.22.
# 1775  원룸         3/4  35   300.0       23     19.8  남동향  24.04.22.
# 1776  원룸         고/4  40   300.0       26    23.14  남동향  24.04.22.
# 1777  원룸         3/4  35   500.0       26    23.14  남동향  24.04.22.
# 1779  원룸         고/3  35   300.0       23    19.84  남동향  24.04.22.
#
#                                                     이미지         위도  ...  \
# 0     /20240424_83/land_naver_1713952322825vWEhO_JPE...  37.484710  ...
# 3     /20240424_158/land_naver_1713952082115BAm9q_JP...  37.474110  ...
# 11    /20240425_96/land_naver_1714015501394lNLip_JPE...  37.469927  ...
# 12    /20240424_240/land_naver_1713951961790HmQA3_JP...  37.486506  ...
# 13    /20240424_181/land_naver_1713952142631HCCmx_JP...  37.480189  ...
# ...                                                 ...        ...  ...
# 1773  /20240422_253/land_naver_1713745347339MhVf4_JP...  37.479770  ...
# 1775  /20240422_251/land_naver_1713745673469CcBwe_JP...  37.477821  ...
# 1776  /20240422_141/land_naver_17137455375894ggHz_JP...  37.486339  ...
# 1777  /20240422_47/land_naver_1713745220011NfDDB_JPE...  37.484921  ...
# 1779  /20240422_259/land_naver_1713755089278QSwLk_JP...  37.483517  ...
#
#                                        설명                          태그 물건층 전체층  \
# 0            2호선 신대방역 확인매물여성취향저격풀옵션치안걱정NO    ['4년이내', '융자금적은', '역세권']   저   4
# 3                      2호선 역세권 가성비 좋은 풀옵션   ['25년이내', '역세권', '화장실한개']   저   3
# 11               2호선 역세권 가성비 좋은 신축 대형 풀옵션  ['10년이내', '화장실한개', '소형평수']   저   4
# 12    2호선 역세권 넓은 1.5룸 가성비 최고 넓은집 찾는다면 여기요   ['2년이내', '화장실한개', '소형평수']   3   4
# 13      역6분 넓은방 깔끔컨디션 채광좋음 풀옵션 즉시입주가능 엘베有   ['25년이내', '융자금없는', '역세권']   6   8
# ...                                   ...                         ...  ..  ..
# 1773            엄청 넓은 신축 원룸 입니다 퀸사이즈 침대가능   ['15년이내', '융자금적은', '역세권']   저   3
# 1775             신림역 채광 NO.1역도보7분양창원룸채광최강   ['25년이내', '융자금적은', '역세권']   3   4
# 1776                    넓고 깔끔한 집입니다 초역세권    ['25년이내', '융자금적은', '역세권']   고   4
# 1777                    신축, 이쁜방 전세자금대출가능    ['2년이내', '융자금적은', '소형평수']   3   4
# 1779                   저렴한 분리형 원룸 방이 넓습니다  ['10년이내', '융자금없는', '세대분리']   고   3
#
#      비선호층여부   tag1   tag2   tag3  tag4  연식
# 0         n   4년이내  융자금적은    역세권  None   4
# 3         n  25년이내    역세권  화장실한개  None  25
# 11        n  10년이내  화장실한개   소형평수  None  10
# 12        n   2년이내  화장실한개   소형평수  None   2
# 13        n  25년이내  융자금없는    역세권  None  25
# ...     ...    ...    ...    ...   ...  ..
# 1773      n  15년이내  융자금적은    역세권  None  15
# 1775      n  25년이내  융자금적은    역세권  None  25
# 1776      n  25년이내  융자금적은    역세권  None  25
# 1777      n   2년이내  융자금적은   소형평수  None   2
# 1779      n  10년이내  융자금없는   세대분리  None  10
#
# [700 rows x 21 columns]

# %% [markdown]
# - 필요한 컬럼만 남기기

# %%
data_filtered.columns
# Out:
# Index(['구분', '층수(물건층/전체층)', '월세', '보증금', '계약면적(m2)', '전용면적(m2)', '방향', '확인일자',
#        '이미지', '위도', '경도', '설명', '태그', '물건층', '전체층', '비선호층여부', 'tag1', 'tag2',
#        'tag3', 'tag4', '연식'],
#       dtype='object')

# %%
data_filtered = data_filtered[['구분','월세','보증금','전용면적(m2)','방향','위도','경도','물건층','전체층','연식']]
data_filtered.head()
# Out:
#     구분  월세     보증금 전용면적(m2)   방향         위도          경도 물건층 전체층  연식
# 0   원룸  40   300.0    16.53  남서향  37.484710  126.911921   저   4   4
# 3   원룸  32   500.0     19.8  남서향  37.474110  126.967600   저   3  25
# 11  원룸  30   500.0     19.8  남동향  37.469927  126.965559   저   4  10
# 12  원룸  45  3000.0    23.14   서향  37.486506  126.952803   3   4   2
# 13  원룸  50  1000.0     23.1   동향  37.480189  126.945238   6   8  25

# %% [markdown]
# - 위도, 경도를 이용하여 역까지의 거리 재기

# %%
coordinate = pd.read_csv(r'Data\서울시 역사마스터 정보.csv')
coordinate = coordinate.query('호선 == "2호선"')
station_list = ['신대방', '신림', '봉천', '서울대입구(관악구청)', '낙성대', '사당']
coordinate.query('역사명 in @station_list')
# Out:
#      역사_ID          역사명   호선         위도          경도
# 727    231          신대방  2호선  37.487462  126.913149
# 728    230           신림  2호선  37.484201  126.929715
# 729    229           봉천  2호선  37.482362  126.941892
# 730    228  서울대입구(관악구청)  2호선  37.481247  126.952739
# 731    227          낙성대  2호선  37.476930  126.963693
# 732    226           사당  2호선  37.476538  126.981544

# %%
from haversine import haversine

haversine((37.487462,126.913149), (37.484201,126.929715), unit = 'm')
# Out:
# 1505.9854014218404

# %%
def distance(station_name, lat, long):
    station_lat = coordinate.query(f'역사명 == "{station_name}"')['위도'].values[0]
    station_long = coordinate.query(f'역사명 == "{station_name}"')['경도'].values[0]

    distance = haversine((station_lat, station_long), (lat, long), unit = 'm')

    return distance

# %%
for s in station_list:
    data_filtered[s] = data_filtered.apply(lambda x: distance(s, x['위도'], x['경도']), axis=1)

# %%
data_filtered.head()
# Out:
#     구분  월세     보증금 전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   원룸  40   300.0    16.53  남서향  37.484710  126.911921   저   4   4
# 3   원룸  32   500.0     19.8  남서향  37.474110  126.967600   저   3  25
# 11  원룸  30   500.0     19.8  남동향  37.469927  126.965559   저   4  10
# 12  원룸  45  3000.0    23.14   서향  37.486506  126.952803   3   4   2
# 13  원룸  50  1000.0     23.1   동향  37.480189  126.945238   6   8  25
#
#             신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0    324.624838  1571.079624  2657.391032  3622.187830  4649.532183
# 3   5028.894601  3526.317039  2447.088993  1532.817356   466.044229
# 11  5018.988995  3538.912171  2504.738374  1692.413227   795.920254
# 12  3500.380635  2053.213460  1067.328720   584.802193  1434.284304
# 13  2944.639577  1440.537335   381.516674   672.260292  1668.344585
#
#              사당
# 0   6210.362767
# 3   1259.773943
# 11  1590.701783
# 12  2767.705540
# 13  3229.353565

# %%
data_filtered['역까지최소거리'] = data_filtered.apply(lambda x: min([x['신대방'], x['신림'], x['봉천'], x['서울대입구(관악구청)'], x['낙성대'], x['사당']]), axis=1)
data_filtered.head()
# Out:
#     구분  월세     보증금 전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   원룸  40   300.0    16.53  남서향  37.484710  126.911921   저   4   4
# 3   원룸  32   500.0     19.8  남서향  37.474110  126.967600   저   3  25
# 11  원룸  30   500.0     19.8  남동향  37.469927  126.965559   저   4  10
# 12  원룸  45  3000.0    23.14   서향  37.486506  126.952803   3   4   2
# 13  원룸  50  1000.0     23.1   동향  37.480189  126.945238   6   8  25
#
#             신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0    324.624838  1571.079624  2657.391032  3622.187830  4649.532183
# 3   5028.894601  3526.317039  2447.088993  1532.817356   466.044229
# 11  5018.988995  3538.912171  2504.738374  1692.413227   795.920254
# 12  3500.380635  2053.213460  1067.328720   584.802193  1434.284304
# 13  2944.639577  1440.537335   381.516674   672.260292  1668.344585
#
#              사당     역까지최소거리
# 0   6210.362767  324.624838
# 3   1259.773943  466.044229
# 11  1590.701783  795.920254
# 12  2767.705540  584.802193
# 13  3229.353565  381.516674

# %%
data_filtered.drop(station_list, axis=1, inplace=True)
data_filtered.head()
# Out:
#     구분  월세     보증금 전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   원룸  40   300.0    16.53  남서향  37.484710  126.911921   저   4   4
# 3   원룸  32   500.0     19.8  남서향  37.474110  126.967600   저   3  25
# 11  원룸  30   500.0     19.8  남동향  37.469927  126.965559   저   4  10
# 12  원룸  45  3000.0    23.14   서향  37.486506  126.952803   3   4   2
# 13  원룸  50  1000.0     23.1   동향  37.480189  126.945238   6   8  25
#
#        역까지최소거리
# 0   324.624838
# 3   466.044229
# 11  795.920254
# 12  584.802193
# 13  381.516674

# %% [markdown]
# ## **분석**

# %% [markdown]
# - 각 항목 분포 확인하기

# %%
for x in ['월세','보증금','전용면적(m2)','연식','역까지최소거리']:
    fig = px.box(data_frame = data_filtered, x=x, width=700, height=400)
    fig.show()

# %% [markdown]
# - 내가 원하는 조건은?
#     - 보증금 3000만원 이하 ✅
#     - 월세는 저렴할수록 좋음
#     - 지하, 반지하, 꼭대기층은 선호하지 않음 ✅
#     - 전용면적이 클수록 좋음
#     - 북향은 선호하지 않음 ✅
#     - 연식이 오래되지 않을수록 좋음
#     - 지하철 역에서 가까울수록 좋음

# %% [markdown]
# - 월세, 전용면적, 연식, 지하철역까지의 거리 점수 매기기

# %%
data_filtered
# Out:
#       구분  월세     보증금 전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     원룸  40   300.0    16.53  남서향  37.484710  126.911921   저   4   4
# 3     원룸  32   500.0     19.8  남서향  37.474110  126.967600   저   3  25
# 11    원룸  30   500.0     19.8  남동향  37.469927  126.965559   저   4  10
# 12    원룸  45  3000.0    23.14   서향  37.486506  126.952803   3   4   2
# 13    원룸  50  1000.0     23.1   동향  37.480189  126.945238   6   8  25
# ...   ..  ..     ...      ...  ...        ...         ...  ..  ..  ..
# 1773  원룸  37   300.0    33.06  남동향  37.479770  126.928582   저   3  15
# 1775  원룸  35   300.0     19.8  남동향  37.477821  126.935265   3   4  25
# 1776  원룸  40   300.0    23.14  남동향  37.486339  126.915350   고   4  25
# 1777  원룸  35   500.0    23.14  남동향  37.484921  126.919564   3   4   2
# 1779  원룸  35   300.0    19.84  남동향  37.483517  126.919409   고   3  10
#
#          역까지최소거리
# 0     324.624838
# 3     466.044229
# 11    795.920254
# 12    584.802193
# 13    381.516674
# ...          ...
# 1773  502.745864
# 1775  772.604019
# 1776  230.882089
# 1777  632.619512
# 1779  705.345544
#
# [700 rows x 11 columns]

# %%
# Convert columns to numeric type if they contain string representations of numbers
data_filtered['전용면적(m2)'] = data_filtered['전용면적(m2)'].astype(float)
data_filtered['역까지최소거리'] = data_filtered['역까지최소거리'].astype(float)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 0 to 1779
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        700 non-null    object
#  1   월세        700 non-null    int64
#  2   보증금       700 non-null    float64
#  3   전용면적(m2)  700 non-null    float64
#  4   방향        700 non-null    object
#  5   위도        700 non-null    float64
#  6   경도        700 non-null    float64
#  7   물건층       700 non-null    object
#  8   전체층       700 non-null    object
#  9   연식        700 non-null    int64
#  10  역까지최소거리   700 non-null    float64
#  11  월세_등급     700 non-null    category
# dtypes: category(1), float64(5), int64(2), object(4)
# memory usage: 66.5+ KB

# %%
data_filtered['월세_등급'] = pd.qcut(data_filtered['월세'], 5, labels=[1,2,3,4,5])
data_filtered['전용면적_등급'] = pd.qcut(data_filtered['전용면적(m2)'], 5, labels=[5,4,3,2,1])
data_filtered['연식_등급'] = pd.qcut(data_filtered['연식'].rank(method='first'), 5, labels=[1,2,3,4,5])
data_filtered['역까지최소거리_등급'] = pd.qcut(data_filtered['역까지최소거리'], 5, labels=[1,2,3,4,5])

# %%
data_filtered
# Out:
#       구분  월세     보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     원룸  40   300.0     16.53  남서향  37.484710  126.911921   저   4   4
# 3     원룸  32   500.0     19.80  남서향  37.474110  126.967600   저   3  25
# 11    원룸  30   500.0     19.80  남동향  37.469927  126.965559   저   4  10
# 12    원룸  45  3000.0     23.14   서향  37.486506  126.952803   3   4   2
# 13    원룸  50  1000.0     23.10   동향  37.480189  126.945238   6   8  25
# ...   ..  ..     ...       ...  ...        ...         ...  ..  ..  ..
# 1773  원룸  37   300.0     33.06  남동향  37.479770  126.928582   저   3  15
# 1775  원룸  35   300.0     19.80  남동향  37.477821  126.935265   3   4  25
# 1776  원룸  40   300.0     23.14  남동향  37.486339  126.915350   고   4  25
# 1777  원룸  35   500.0     23.14  남동향  37.484921  126.919564   3   4   2
# 1779  원룸  35   300.0     19.84  남동향  37.483517  126.919409   고   3  10
#
#          역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 0     324.624838     2       5     1          2
# 3     466.044229     1       4     3          4
# 11    795.920254     1       4     1          5
# 12    584.802193     3       2     1          4
# 13    381.516674     3       2     3          3
# ...          ...   ...     ...   ...        ...
# 1773  502.745864     1       1     3          4
# 1775  772.604019     1       4     5          5
# 1776  230.882089     2       2     5          1
# 1777  632.619512     1       2     1          5
# 1779  705.345544     1       3     2          5
#
# [700 rows x 15 columns]

# %%
data_filtered_final = data_filtered.query('월세_등급 <= 3 and 전용면적_등급 <= 1 and 연식_등급 <= 2 and 역까지최소거리_등급 <= 2')
data_filtered_final
# Out:
#       구분  월세     보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     원룸  40   300.0     16.53  남서향  37.484710  126.911921   저   4   4
# 19    원룸  50   500.0     19.80   남향  37.485085  126.941380   고   3   4
# 31    원룸  37   300.0     18.18  남동향  37.483274  126.945350   저   4  10
# 39    원룸  50  1000.0     19.83   남향  37.478004  126.964249   2   5   2
# 87    원룸  44  2000.0     19.83   동향  37.481315  126.942018   2   4  10
# ...   ..  ..     ...       ...  ...        ...         ...  ..  ..  ..
# 1659  원룸  45   500.0     19.84  남동향  37.486125  126.928411   2  10  10
# 1681  원룸  42   500.0     26.46  남동향  37.485385  126.928474   고  10  10
# 1690  원룸  40   500.0     21.49  남동향  37.485212  126.928696   중  11  10
# 1733  원룸  40   500.0     19.80   동향  37.479568  126.962835   저   3  10
# 1745  원룸  50  1000.0     19.84  남동향  37.478612  126.954048   2   3  10
#
#          역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 0     324.624838     2       5     1          2
# 19    306.135966     3       4     1          2
# 31    321.535298     1       4     1          2
# 39    129.109247     3       3     1          1
# 87    116.950922     2       3     1          1
# ...          ...   ...     ...   ...        ...
# 1659  242.916318     3       3     2          1
# 1681  171.240151     2       1     2          1
# 1690  143.951168     2       2     2          1
# 1733  302.946145     2       4     2          2
# 1745  314.944945     3       3     2          2
#
# [66 rows x 15 columns]

# %% [markdown]
# - 최종 매물 리스트 시각화

# %%
f = folium.Figure(width=700, height=500)
m = folium.Map(location=[37.486313, 126.935378], zoom_start=14).add_to(f)

for idx in data_filtered_final.index:
    lat = data_filtered_final.loc[idx, '위도']
    long = data_filtered_final.loc[idx, '경도']
    num = data_filtered_final.loc[idx, '구분']

    folium.Marker([lat, long]
                  , popup=f"<a href=https://m.land.naver.com/article/info/{num}>링크</a>"
                  ).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27e906f9be6047f329300ab794a50112 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27e906f9be6047f329300ab794a50112&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27e906f9be6047f329300ab794a50112 = L.map(
#                 &quot;map_27e906f9be6047f329300ab794a50112&quot;,
#                 {
#                     center: [37.486313, 126.935378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e8c8dc09f7219b046be9ff3967ddb38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e8c8dc09f7219b046be9ff3967ddb38.addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#             var marker_9494ab7b0fecda2cc1f47a71d1595b71 = L.marker(
#                 [37.48471, 126.911921],
#                 {}
#             ).addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#         var popup_5880d629c05e4e2bf6eb6fb3b15ec85e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54d1e2441afe70e72ab33d783a062a4c = $(`&lt;div id=&quot;html_54d1e2441afe70e72ab33d783a062a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/원룸&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_5880d629c05e4e2bf6eb6fb3b15ec85e.setContent(html_54d1e2441afe70e72ab33d783a062a4c);
#
#
#
#         marker_9494ab7b0fecda2cc1f47a71d1595b71.bindPopup(popup_5880d629c05e4e2bf6eb6fb3b15ec85e)
#         ;
#
#
#
#
#             var marker_a252758a099838d236a0dd36dc5ea899 = L.marker(
#                 [37.485085, 126.94138],
#                 {}
#             ).addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#         var popup_c0e1ef05e7bded8c7cf8c282c07cba17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc026bf155dc2c584d645db52389f2a8 = $(`&lt;div id=&quot;html_bc026bf155dc2c584d645db52389f2a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/원룸&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_c0e1ef05e7bded8c7cf8c282c07cba17.setContent(html_bc026bf155dc2c584d645db52389f2a8);
#
#
#
#         marker_a252758a099838d236a0dd36dc5ea899.bindPopup(popup_c0e1ef05e7bded8c7cf8c282c07cba17)
#         ;
#
#
#
#
#             var marker_d9b43d8a9491a59c269ef037c835f223 = L.marker(
#                 [37.483274, 126.94535],
#                 {}
#             ).addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#         var popup_32a3808543fa49d472895fbedeccc89b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a559cb7acc100ef45775fc9af3b76d64 = $(`&lt;div id=&quot;html_a559cb7acc100ef45775fc9af3b76d64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/원룸&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_32a3808543fa49d472895fbedeccc89b.setContent(html_a559cb7acc100ef45775fc9af3b76d64);
#
#
#
#         marker_d9b43d8a9491a59c269ef037c835f223.bindPopup(popup_32a3808543fa49d472895fbedeccc89b)
#         ;
#
#
#
#
#             var marker_1266e61211f49b75a9c89bd57607ce62 = L.marker(
#                 [37.478004, 126.964249],
#                 {}
#             ).addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#         var popup_69d124cd2b965b865165978bb2946a6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b6bf62c7ff26fd8cb39599a9471f620 = $(`&lt;div id=&quot;html_8b6bf62c7ff26fd8cb39599a9471f620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/원룸&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_69d124cd2b965b865165978bb2946a6e.setContent(html_8b6bf62c7ff26fd8cb39599a9471f620);
#
#
#
#         marker_1266e61211f49b75a9c89bd57607ce62.bindPopup(popup_69d124cd2b965b865165978bb2946a6e)
#         ;
#
#
#
#
#             var marker_dab728f9f759cf2baa001775639493ae = L.marker(
#                 [37.481315, 126.942018],
#                 {}
#             ).addTo(map_27e906f9be6047f329300ab794a50112);
#
#
#         var popup_12cb28b3bb691a9f534e89d53291298a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1560b9258f198a196a6efe146a0ab922 = $(`&lt;div id=&quot;html_1560b9258f198a196a6efe146a0ab922&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/원룸&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_12cb28b3bb691a9f534e89d53291298a.setContent(html_1560b9258f198a196a6efe146a0ab922);
#
#
#
#         marker_dab728f9f759cf2baa001775639493ae.bindPopup(popup_12cb28b3bb691a9f534e89d53291298a)
#         ;
#
#
#
#
#             var marker_7addc451c0ca36635ca424993ec2d8af = L.marker(
#                 [37.486568, 126.927434],
